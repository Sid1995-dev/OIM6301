# %%
# exercise 1.1
a = 3 #this is an assignment statement. a takes 3 as value
a + 2 #return type is int and return value is 5.

# %%
# exercise 1.2
a = a + 1.0 #this is the assignment statement where a gets assigned 4.0 as the value. 
a #return value is 4.0 and return type is float.

# %%
# exercise 1.3
a = 3 #this here is the assignment statement. a is assigned 3 as value.
b #this one throws an error since b isn't defined.

# %%
# exercise 1.4
a = 3 #this is the assignment statement where a is assigned value 3.
a == 5.0 #this compares whether a equals 5.0. It returns False because the comparison is not the same.
a #the value of a remains 3. the return type is int.

# %%
# exercise 1.5
b = 10  #this is an assignment statement where b takes 10 as its value.
c = b > 9  #this checks if b is greater than 9. It then returns True because 10 > 9.
c  #Here it returns True. The type of c is boolean.

# %%
# exercise 1.6
5/2 == 5/2.0  #this checks if 5 divided by 2 equals 5 divided by 2.0.
#Here both evaluate to 2.5, so the result is True. type of result is boolean.

# %%
# exercise 2.1
3.0 - 1.0 != 5.0 - 3.0  #this checks whether (3.0 - 1.0) is NOT equal to (5.0 - 3.0).
#left side = 2.0, right side = 2.0. They are equal, so "!=" returns as False.
#Therefore final result = False.

# %%
# exercise 2.2
3 > 4 or (2 < 3 and 9 > 10) #check the inner part first.
#2 < 3 is True, 9 > 10 is False, so (True and False) = False.
#3 > 4 happens to be False.
#now (False or False) = False.
#final result = False.

# %%
# exercise 2.3
4 > 5 or 3 < 4 and 9 > 8 #check the "and" part first (it has higher priority).
#(3 < 4 and 9 > 8) is True and True = True.
#now we have (4 > 5 or True) is False or True = True.
#Final result = True.

# %%
# exercise 2.4
not(4 > 3 and 100 > 6) #inside parentheses: (4 > 3 and 100 > 6) is True and True = True.
#Applying "not" flips it up. not(True) = False.
#Final result = False.

# %%
# exercise 3. Using the time module
import time  # this imports the built-in time module

print(time.time())  
# time.time() returns the current time in seconds since the "epoch" (Jan 1, 1970).
# the return value is a float representing seconds.
# for example: 1730675152.457893
# return type: float
# Out:
# 1762224608.1504252

# %%
# exercise 4. Program to calculate sum, difference, product, quotient, and exponentiation of two integers

# prompt the user to enter two integers
a = int(input("Enter the first integer: "))
b = int(input("Enter the second integer: "))

# perform calculations
sum_ = a + b
diff = a - b
prod = a * b
quot = a / b
expo = a ** b   # use ** for exponentiation (not ^)

# display results using f-strings
print(f"{a} + {b} = {sum_}")
print(f"{a} - {b} = {diff}")
print(f"{a} * {b} = {prod}")
print(f"{a} / {b} = {quot}")
print(f"{a} ^ {b} = {expo}")
# Out:
# Enter the first integer:  2
# Enter the second integer:  3
# 2 + 3 = 5
# 2 - 3 = -1
# 2 * 3 = 6
# 2 / 3 = 0.6666666666666666
# 2 ^ 3 = 8
